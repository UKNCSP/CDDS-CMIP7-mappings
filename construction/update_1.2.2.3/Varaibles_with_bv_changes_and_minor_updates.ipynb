# %%
import json
import os

# %%
from dr_issue import *

# %%
data_v1223 = json.load(open('v1223.json'))['Compound Name']
labels = json.load(open('labels.json'))

# %%
field_mapping = {
    'cmip6_compound_name': 'Key',
    'branded_variable_name': 'Branded variable name',
    'standard_name': 'CF standard name',
    'long_name' : 'Long name',
    'comment': 'Comment',    
    'dimensions': 'Dimensions',
    'frequency': 'Frequency',
    'units': 'Units'    ,
    'positive': 'Positive',
    'processing_note': 'Processing notes',
    'cell_methods': 'Cell methods',
    'cell_measures': 'Cell measures',    
    'modeling_realm': 'Modeling realm',
    'region': 'Region'
}

# UNCHECKED: Variable status and CMIP6 differences

# %%
from collections import defaultdict

# %%
changes_dict = defaultdict(lambda: defaultdict(list))
todo = []
title_changes = []
missing = []
change_type_count = defaultdict(int)
changed_issues = []
for cmip7_cn, v in data_v1223.items():
    cmip6_cn = v['cmip6_compound_name']
    filename = f'issues/{cmip6_cn}'
    if not os.path.exists(filename):
        print(f"Nope: {filename}")
        missing.append(filename)
        continue
            
    dri = DRIssue()
    dri.read_file(filename)
    
    changes = False
    problems = []
    for field_i, field_d in field_mapping.items():
        dr_field_value = v[field_i]
        if isinstance(dr_field_value, str):
            dr_field_value = dr_field_value.strip().replace("  ", " ")
            dr_field_value = dr_field_value.strip().replace("\n", "; ")
        if not dr_field_value == dri.dr_info[field_d]:
            
            problems.append(f'\tdr    {field_i}: {dr_field_value}\n'
                            f'\tissue {field_d}: {dri.dr_info[field_d]}')

            changes_dict[field_d][filename].append(f'"{dri.dr_info[field_d]}" -> "{dr_field_value}"')
            dri.dr_info[field_d] = dr_field_value
            if dri.dr_notes[field_d]:
                dri.dr_notes[field_d] += '; '
            dri.dr_notes[field_d] += "Updated for consistency with DR v1.2.2.3"
            change_type_count[field_i] += 1

    if problems:
        print(f'{filename}')
        print("\n".join(problems))
        changes = True
        changed_issues.append([labels[cmip6_cn]['number'], filename])

    expected_title = f'Variable {cmip7_cn} ({cmip6_cn})'
    title = labels[cmip6_cn]['title']
    if expected_title != title:
        title_changes.append([labels[cmip6_cn]['number'], expected_title])

    
    if changes:
        dri.write_file(filename)
        todo.append(filename)
# Out:
# issues/AERmon.abs550bc
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.abs550dust
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.abs550no3
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.abs550oa
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.abs550so4
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.abs550ss
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/Eday.ccldncl
# 	dr    modeling_realm: aerosol atmos atmosChem
# 	issue Modeling realm: aerosol
# issues/Emon.ccldncl
# 	dr    modeling_realm: aerosol atmos atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.ccnSouth30
# Nope: issues/AERmon.ccn1South30
# issues/AERmon.ccn1
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.ccn02South30
# issues/AERmon.ccn02
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.cdncSouth30
# issues/AERmon.co
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.co
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.codSouth30
# issues/AERmon.conccn
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.conccn
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.dryno3
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/6hrLev.ec550aer
# 	dr    branded_variable_name: ec550aer_tpt-al-hxy-u
# 	issue Branded variable name: ec550aer_tpt-u-hxy-u
# 	dr    dimensions: longitude latitude alevel time1 lambda550nm
# 	issue Dimensions: longitude latitude time1 lambda550nm
# 	dr    processing_note: CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: point CMIP7:area: mean (weighted by downwelling solar radiation) time: point,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude alevel time1 lambda550nm CMIP7:longitude latitude time1 lambda550nm, nCHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: point CMIP7:area: mean (weighted by downwelling solar radiation) time: point,
# issues/AERmon.emibbbc
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbch4
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbco
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbdms
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbnh3
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbnox
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibboa
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbso2
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERmon.emibbvoc
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.emidmsSouth30
# issues/AERmon.emilnox
# 	dr    branded_variable_name: emilnox_tavg-u-hxy-u
# 	issue Branded variable name: emilnox_tavg-al-hxy-u
# 	dr    standard_name: tendency_of_atmosphere_mass_content_of_nox_expressed_as_nitrogen_due_to_emission
# 	issue CF standard name: tendency_of_atmosphere_mole_concentration_of_nox_expressed_as_nitrogen
# 	dr    dimensions: longitude latitude time
# 	issue Dimensions: longitude latitude alevel time
# 	dr    units: kg m-2 s-1
# 	issue Units: mol s-1
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude alevel time CMIP7:longitude latitude time,; CHANGE SINCE CMIP6 in Units (from Physical Parameter) - CMIP6:mol s-1 CMIP7:kg m-2 s-1,
# 	issue Processing notes:
# Nope: issues/AERmon.emissSouth30
# issues/AERmon.mmraerh2o
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmraerh2o
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmraerh2o
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrbcSouth30
# issues/AERmon.mmrbc
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrbc
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrbc
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrdustSouth30
# issues/AERmon.mmrdust
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrdust
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrdust
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrnh4South30
# issues/AERmon.mmrnh4
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrnh4
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrnh4
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrno3South30
# issues/AERmon.mmrno3
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrno3
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrno3
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmroaSouth30
# issues/AERmon.mmroa
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmroa
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmroa
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrpm1South30
# Nope: issues/AERmon.mmrpm2p5South30
# Nope: issues/AERmon.mmrso4South30
# issues/AERmon.mmrso4
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrso4
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrso4
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrsoaSouth30
# issues/AERmon.mmrsoa
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrsoa
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrssSouth30
# issues/AERmon.mmrss
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.mmrss
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.mmrss
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERhr.sfno2
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly. CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# issues/AERhr.sfo3
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly. CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# issues/AERday.sfo3max
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly. CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# Nope: issues/AERmon.od550aerSouth30
# issues/Emon.reffccwctop
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.reffclwtopSouth30
# issues/AERhr.sfpm1
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.sfpm1
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.mmrpm10South30
# issues/AERhr.sfpm10
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERday.sfpm10
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/AERhr.sfpm25
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly. CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# issues/AERday.sfpm25
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/AERmon.so2South30
# issues/AERday.so2
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# issues/E3hrPt.so2
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# 	dr    modeling_realm: aerosol atmosChem
# 	issue Modeling realm: aerosol
# Nope: issues/CFmon.albisccpSouth30
# issues/fx.areacella
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# issues/E1hr.bldep
# 	dr    modeling_realm: atmos aerosol land
# 	issue Modeling realm: atmos
# issues/AERmon.bldep
# 	dr    modeling_realm: atmos aerosol land
# 	issue Modeling realm: atmos
# issues/3hrPt.bldep
# 	dr    modeling_realm: atmos aerosol land
# 	issue Modeling realm: atmos
# Nope: issues/Amon.clSouth30
# Nope: issues/CFmon.clcSouth30
# Nope: issues/CFmon.clhcalipsoSouth30
# Nope: issues/CFmon.clmcalipsoSouth30
# Nope: issues/CFmon.cllcalipsoSouth30
# Nope: issues/CFmon.clcalipsoSouth30
# Nope: issues/Amon.cliSouth30
# Nope: issues/CFmon.clicSouth30
# Nope: issues/CFmon.clisSouth30
# Nope: issues/CFmon.clisccpSouth30
# Nope: issues/Amon.cliviSouth30
# Nope: issues/CFmon.clivimodisSouth30
# Nope: issues/CFmon.clmodisSouth30
# Nope: issues/CFmon.clmodisiceSouth30
# Nope: issues/CFmon.clmodisliquidSouth30
# Nope: issues/CFmon.clsSouth30
# Nope: issues/Amon.cltSouth30
# issues/AERmon.cltc
# 	dr    modeling_realm: atmos aerosol
# 	issue Modeling realm: atmos
# Nope: issues/CFmon.cltcalipsoSouth30
# Nope: issues/CFmon.cltisccpSouth30
# Nope: issues/CFmon.cltmodisSouth30
# Nope: issues/Amon.clwSouth30
# Nope: issues/CFmon.clwcSouth30
# Nope: issues/CFmon.clwsSouth30
# Nope: issues/Amon.clwviSouth30
# Nope: issues/CFmon.clwvimodisSouth30
# issues/AERmon.co2
# 	dr    modeling_realm: atmos aerosol
# 	issue Modeling realm: atmos
# issues/Emon.co2s
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly. CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:longitude latitude time CMIP7:longitude latitude time height2m,
# issues/Amon.co2
# 	dr    modeling_realm: atmos aerosol
# 	issue Modeling realm: atmos
# issues/Amon.co2Clim
# 	dr    processing_note: Report only for simulations (e.g., prescribed concentration pi-control run), in which the CO2 does not vary from one year to the next. Report 12 monthly values, starting with January, even if the values do not vary seasonally. When calling CMOR, identify this variable as co2Clim, not co2.  If CO2 is spatially uniform, omit this field, but report Total Atmospheric Mass of CO2 (see the table entry after the next). Are these the preferred units or should it be a unitless fraction? Should this field be reported instead on model levels? Or should we also require either the vertically integrated mole fraction (or mass?) of this species or the vertically integrated globally averaged mole fraction (or mass?)? CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: mean within years time: mean over years CMIP7:area: mean where air time: mean within years time: mean over years,
# 	issue Processing notes: Report only for simulations (e.g., prescribed concentration pi-control run), in which the CO2 does not vary from one year to the next. Report 12 monthly values, starting with January, even if the values do not vary seasonally. When calling CMOR, identify this variable as co2Clim, not co2. If CO2 is spatially uniform, omit this field, but report Total Atmospheric Mass of CO2 (see the table entry after the next). Are these the preferred units or should it be a unitless fraction? Should this field be reported instead on model levels? Or should we also require either the vertically integrated mole fraction (or mass?) of this species or the vertically integrated globally averaged mole fraction (or mass?)? CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: mean within years time: mean over years CMIP7:area: mean where air time: mean within years time: mean over years,
# 	dr    modeling_realm: atmos aerosol
# 	issue Modeling realm: atmos
# issues/Amon.co2massClim
# 	dr    processing_note: Report only for simulations (e.g., prescribed concentration pi-control run), in which the CO2 does not vary from one year to the next. Report 12 monthly values, starting with January, even if the values do not vary seasonally. When calling CMOR, identify this variable as co2massClim, not co2mass. If CO2 is spatially nonuniform, omit this field, but report Mole Fraction of CO2 (see the table entry before the previous one).; CHANGE SINCE CMIP6: compound name,; CHANGE SINCE CMIP6 in Units (from Physical Parameter) - CMIP6:kg CMIP7:mol mol-1, CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: mean within years time: mean over years CMIP7:height: sum (through atmospheric column) area: sum time: mean within years time: mean over years,
# 	issue Processing notes: Report only for simulations (e.g., prescribed concentration pi-control run), in which the CO2 does not vary from one year to the next. Report 12 monthly values, starting with January, even if the values do not vary seasonally. When calling CMOR, identify this variable as co2massClim, not co2mass. If CO2 is spatially nonuniform, omit this field, but report Mole Fraction of CO2 (see the table entry before the previous one). CHANGE SINCE CMIP6: compound name, CHANGE SINCE CMIP6 in Units (from Physical Parameter) - CMIP6:kg CMIP7:mol mol-1, CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: mean within years time: mean over years CMIP7:height: sum (through atmospheric column) area: sum time: mean within years time: mean over years,
# 	dr    modeling_realm: atmos aerosol
# 	issue Modeling realm: atmos
# Nope: issues/CFmon.dmcSouth30
# issues/CFmon.dmc
# 	dr    comment: The net mass flux represents the difference between the updraft and downdraft components.  This is calculated as the convective mass flux divided by the area of the whole grid cell (not just the area of the cloud).
# 	issue Comment: The net mass flux represents the difference between the updraft and downdraft components. This is calculated as the convective mass flux divided by the area of the whole grid cell (not just the area of the cloud).
# Nope: issues/CFmon.edtSouth30
# issues/Eday.evspsbl
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# issues/Amon.evspsbl
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# issues/CFsubhr.evspsbl
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# Nope: issues/CFmon.evuSouth30
# issues/ImonAnt.hfls
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.hfls
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.hflsSouth30
# issues/ImonAnt.hfss
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.hfss
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.hfssSouth30
# Nope: issues/CFmon.hurSouth30
# Nope: issues/Amon.hurSouth30
# Nope: issues/E1hr.hursSouth30
# Nope: issues/Amon.hursSouth30
# Nope: issues/CFmon.husSouth30
# Nope: issues/Amon.husSouth30
# Nope: issues/Amon.hussSouth30
# issues/fx.lat
# 	dr    processing_note: the fx.lon comment also applies to latitude.; CHANGE SINCE CMIP6: compound name,
# 	issue Processing notes: the fx.lon comment also applies to latitude. CHANGE SINCE CMIP6: compound name,
# issues/fx.lon
# 	dr    processing_note: Note that the CF convention and CMOR2 require that this field will be included in each file that contains a variable that is a function of the "site" dimension, so there is no need to save this field by itself. It is included here simply to indicate that longitudes should be stored for the site grid in each file written.; CHANGE SINCE CMIP6: compound name,
# 	issue Processing notes: Note that the CF convention and CMOR2 require that this field will be included in each file that contains a variable that is a function of the "site" dimension, so there is no need to save this field by itself. It is included here simply to indicate that longitudes should be stored for the site grid in each file written. CHANGE SINCE CMIP6: compound name,
# Nope: issues/CFmon.mcdSouth30
# Nope: issues/CFmon.mcuSouth30
# issues/day.noaahi2m
# 	dr    comment: mean 2m daily NOAA heat index.; The perceived air temperature when relative humidity is taken into consideration (which makes it feel hotter than the actual air temperature).; The heat index is only defined when the ambient air temperature is at or above 299.817 K.; NOAA heat index = -42.379 + 2.04901523(T) + 10.14333127(R) - 0.22475541(T)(R) - 6.83783e-3 sqr(T) - 5.481717e-2 sqr(R) + 1.22874e-3 sqr(T) (R) + 8.5282e-4 (T) sqr(R) - 1.99e-6 sqr(T) sqr(R); where T is 2 m temperature (degrees F), R is relative humidity (%)
# 	issue Comment: mean 2m daily NOAA heat index. The perceived air temperature when relative humidity is taken into consideration (which makes it feel hotter than the actual air temperature). The heat index is only defined when the ambient air temperature is at or above 299.817 K. NOAA heat index = -42.379 + 2.04901523(T) + 10.14333127(R) - 0.22475541(T)(R) - 6.83783e-3 sqr(T) - 5.481717e-2 sqr(R) + 1.22874e-3 sqr(T) (R) + 8.5282e-4 (T) sqr(R) - 1.99e-6 sqr(T) sqr(R) where T is 2 m temperature (degrees F), R is relative humidity (%)
# 	dr    processing_note: NOAA heat index = -42.379 + 2.04901523T + 10.14333127R - 0.22475541TR - 6.83783 x 10-3T2 - 5.481717 x 10-2R2 + 1.22874 x 10-3T2R + 8.5282 x 10-4TR2 - 1.99 x 10-6T2R2; where T is 2 m temperature (degrees F), R is relative humidity (%).; Heat index is only defined when the ambient air temperature is at or above 299.817 K.
# 	issue Processing notes: NOAA heat index = -42.379 + 2.04901523T + 10.14333127R - 0.22475541TR - 6.83783 x 10-3T2 - 5.481717 x 10-2R2 + 1.22874 x 10-3T2R + 8.5282 x 10-4TR2 - 1.99 x 10-6T2R2 where T is 2 m temperature (degrees F), R is relative humidity (%). Heat index is only defined when the ambient air temperature is at or above 299.817 K.
# issues/day.noaahi2mmax
# 	dr    comment: max 2m daily NOAA heat index ; The perceived air temperature when relative humidity is taken into consideration (which makes it feel hotter than the actual air temperature).; The heat index is only defined when the ambient air temperature is at or above 299.817 K.; NOAA heat index = -42.379 + 2.04901523(T) + 10.14333127(R) - 0.22475541(T)(R) - 6.83783e-3 sqr(T) - 5.481717e-2 sqr(R) + 1.22874e-3 sqr(T) (R) + 8.5282e-4 (T) sqr(R) - 1.99e-6 sqr(T) sqr(R); where T is 2 m temperature (degrees F), R is relative humidity (%)
# 	issue Comment: max 2m daily NOAA heat index The perceived air temperature when relative humidity is taken into consideration (which makes it feel hotter than the actual air temperature). The heat index is only defined when the ambient air temperature is at or above 299.817 K. NOAA heat index = -42.379 + 2.04901523(T) + 10.14333127(R) - 0.22475541(T)(R) - 6.83783e-3 sqr(T) - 5.481717e-2 sqr(R) + 1.22874e-3 sqr(T) (R) + 8.5282e-4 (T) sqr(R) - 1.99e-6 sqr(T) sqr(R) where T is 2 m temperature (degrees F), R is relative humidity (%)
# 	dr    processing_note: NOAA heat index = -42.379 + 2.04901523T + 10.14333127R - 0.22475541TR - 6.83783 x 10-3T2 - 5.481717 x 10-2R2 + 1.22874 x 10-3T2R + 8.5282 x 10-4TR2 - 1.99 x 10-6T2R2; where T is 2 m temperature (degrees F), R is relative humidity (%).; The heat index is only defined when the ambient air temperature is at or above 299.817 K.
# 	issue Processing notes: NOAA heat index = -42.379 + 2.04901523T + 10.14333127R - 0.22475541TR - 6.83783 x 10-3T2 - 5.481717 x 10-2R2 + 1.22874 x 10-3T2R + 8.5282 x 10-4TR2 - 1.99 x 10-6T2R2 where T is 2 m temperature (degrees F), R is relative humidity (%). The heat index is only defined when the ambient air temperature is at or above 299.817 K.
# Nope: issues/CFmon.pctisccpSouth30
# Nope: issues/Amon.pfullSouth30
# Nope: issues/E1hr.prSouth30
# Nope: issues/Amon.prSouth30
# Nope: issues/Amon.prcSouth30
# issues/ImonAnt.prra
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.prra
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.prraSouth30
# issues/ImonAnt.prsn
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.prsn
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.prsnSouth30
# Nope: issues/Amon.prwSouth30
# Nope: issues/Amon.psSouth30
# Nope: issues/E1hr.psSouth30
# Nope: issues/Amon.pslSouth30
# issues/Eday.reffcclwtop
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# issues/Emon.reffcclwtop
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# Nope: issues/Emon.reffclicSouth30
# Nope: issues/Emon.reffclisSouth30
# Nope: issues/Emon.reffclwcSouth30
# Nope: issues/Emon.reffclwsSouth30
# issues/Eday.reffsclwtop
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# issues/Emon.reffsclwtop
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# issues/ImonAnt.rlds
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.rlds
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/E1hr.rldsSouth30
# Nope: issues/Amon.rldsSouth30
# Nope: issues/Amon.rldscsSouth30
# issues/ImonAnt.rlus
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.rlus
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.rlusSouth30
# Nope: issues/Amon.rlutSouth30
# Nope: issues/Amon.rlutcsSouth30
# issues/ImonAnt.rsds
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# issues/ImonGre.rsds
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land
# 	issue Modeling realm: atmos
# Nope: issues/E1hr.rsdsSouth30
# Nope: issues/Amon.rsdsSouth30
# Nope: issues/Amon.rsdscsSouth30
# Nope: issues/Amon.rsdtSouth30
# issues/ImonAnt.rsus
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.rsus
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# Nope: issues/Amon.rsusSouth30
# Nope: issues/Amon.rsuscsSouth30
# Nope: issues/Amon.rsutSouth30
# Nope: issues/Amon.rsutcsSouth30
# issues/CFsubhr.sci
# 	dr    comment: Fraction of time that shallow convection occurs in the grid cell. Variable is binary, indicating whether at each time step convection occurs (1.0), or not (0.0).
# 	issue Comment: Fraction of time that shallow convection occurs in the grid cell. Variable is binary, indicating whether at each time step convection occurs (1.0), or not (0.0).
# issues/Eday.scldncl
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# issues/Emon.scldncl
# 	dr    modeling_realm: atmos atmosChem aerosol
# 	issue Modeling realm: atmos
# Nope: issues/E1hr.sfcWindSouth30
# Nope: issues/Amon.sfcWindSouth30
# Nope: issues/CFmon.taSouth30
# Nope: issues/Amon.taSouth30
# issues/6hrPlevPt.ta
# 	dr    processing_note: On the following pressure levels: 850, 500, 250 hPa; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: point CMIP7:area: mean where air time: point,
# 	issue Processing notes: On the following pressure levels: 850, 500, 250 hPa CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean time: point CMIP7:area: mean where air time: point,
# issues/ImonAnt.tas
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.tas
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/AERhr.tas
# 	dr    processing_note: Given the large differences in aerosol, boundary layer and vertical coordinate schemes across the models AerChemMIP do not want to be prescriptive and am happy to accept modelling centre's 'best estimate' rather than requiring interpolation to 2m exactly.
# 	issue Processing notes:
# Nope: issues/Amon.tasSouth30
# Nope: issues/Amon.tasmaxSouth30
# Nope: issues/Amon.tasminSouth30
# issues/CFmon.tnhusd
# 	dr    comment: This includes any horizontal or vertical numerical moisture diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics.  This term is required to check the closure of the moisture budget.
# 	issue Comment: This includes any horizontal or vertical numerical moisture diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics. This term is required to check the closure of the moisture budget.
# issues/CFsubhr.tnhusd
# 	dr    comment: This includes any horizontal or vertical numerical moisture diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics.  This term is required to check the closure of the moisture budget.
# 	issue Comment: This includes any horizontal or vertical numerical moisture diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics. This term is required to check the closure of the moisture budget.
# issues/Emon.tntd
# 	dr    comment: This includes any horizontal or vertical numerical temperature diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics.  This term is required to check the closure of the temperature budget.
# 	issue Comment: This includes any horizontal or vertical numerical temperature diffusion not associated with the parametrized moist physics or the resolved dynamics. For example, any vertical diffusion which is part of the boundary layer mixing scheme should be excluded, as should any diffusion which is included in the terms from the resolved dynamics. This term is required to check the closure of the temperature budget.
# issues/ImonAnt.ts
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xant yant time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/ImonGre.ts
# 	dr    processing_note: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,; CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:longitude latitude time,
# 	issue Processing notes: CHANGE SINCE CMIP6 in Dimensions - CMIP6:xgre ygre time CMIP7:latitude longitude time,
# 	dr    modeling_realm: atmos land landIce
# 	issue Modeling realm: atmos
# issues/Eday.tsns
# 	dr    branded_variable_name: ts_tavg-u-hxy-lnd
# 	issue Branded variable name: ts_tavg-u-hxy-sn
# 	dr    processing_note: CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where land time: mean CMIP7:area: mean where land time: mean (weighted by snow area),; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where land time: mean CMIP7:area: time: mean where snow (on land),
# 	issue Processing notes: CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where land time: mean CMIP7:area: mean where land time: mean (weighted by snow area), CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where land time: mean CMIP7:area: time: mean where snow (on land),
# Nope: issues/Amon.tsSouth30
# Nope: issues/Amon.uaSouth30
# issues/6hrLev.ua
# 	dr    processing_note: on all model levels. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:time: point CMIP7:area: mean time: point,; CHANGE SINCE CMIP6 in Cell Measures - CMIP6:::OPT CMIP7:area: areacella,
# 	issue Processing notes: on all model levels. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:time: point CMIP7:area: mean time: point,
# Nope: issues/Amon.uasSouth30
# Nope: issues/Amon.vaSouth30
# issues/6hrLev.va
# 	dr    processing_note: on all model levels; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:time: point CMIP7:area: mean time: point,; CHANGE SINCE CMIP6 in Cell Measures - CMIP6:::OPT CMIP7:area: areacella,
# 	issue Processing notes: on all model levels CHANGE SINCE CMIP6 in Cell Methods - CMIP6:time: point CMIP7:area: mean time: point,
# Nope: issues/Amon.vasSouth30
# Nope: issues/Amon.wapSouth30
# issues/day.wbgt2m
# 	dr    comment: mean 2m daily wet bulb globe temperature (WBGT). ; Wet Bulb Globe Temperature (WBGT) is a particularly effective indicator of heat stress for active populations such as outdoor workers and athletes.; The calculation should be done with: ; WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air and "P = surface pressure in Pa"
# 	issue Comment: mean 2m daily wet bulb globe temperature (WBGT). Wet Bulb Globe Temperature (WBGT) is a particularly effective indicator of heat stress for active populations such as outdoor workers and athletes. The calculation should be done with: WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air and "P = surface pressure in Pa"
# 	dr    processing_note: The calculation should be done with: ; WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, ; where T_C is temperature in degrees C, ; and e = huss \* p \* M_air / M_H2O, ; where "huss=specific humidity in kg/kg", ; M_H2O = 18.01528/1000 # kg/mol, ; M_air = 28.964/1000 # kg/mol for dry air,; and "P = surface pressure in Pa"
# 	issue Processing notes: The calculation should be done with: WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air, and "P = surface pressure in Pa"
# issues/day.wbgt2mmax
# 	dr    comment: max 2m daily wet bulb globe temperature (WGBT): ; Wet Bulb Globe Temperature (WBGT) is a particularly effective indicator of heat stress for active populations such as outdoor workers and athletes.; The calculation should be done with: ; WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air and "P = surface pressure in Pa"
# 	issue Comment: max 2m daily wet bulb globe temperature (WGBT): Wet Bulb Globe Temperature (WBGT) is a particularly effective indicator of heat stress for active populations such as outdoor workers and athletes. The calculation should be done with: WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air and "P = surface pressure in Pa"
# 	dr    processing_note: The calculation should be done with: ; WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, ; where T_C is temperature in degrees C, ; and e = huss \* p \* M_air / M_H2O, ; where "huss=specific humidity in kg/kg", ; M_H2O = 18.01528/1000 # kg/mol, ; M_air = 28.964/1000 # kg/mol for dry air,; and "P = surface pressure in Pa"
# 	issue Processing notes: The calculation should be done with: WBGT = 0.567 \* T_C + 0.393 \* e/100 + 3.94, where T_C is temperature in degrees C, and e = huss \* p \* M_air / M_H2O, where "huss=specific humidity in kg/kg", M_H2O = 18.01528/1000 # kg/mol, M_air = 28.964/1000 # kg/mol for dry air, and "P = surface pressure in Pa"
# Nope: issues/Amon.zgSouth30
# issues/AERmon.c2h4
# 	dr    modeling_realm: atmosChem aerosol
# 	issue Modeling realm: atmosChem
# issues/AERmon.c2h5oh
# 	dr    modeling_realm: atmosChem aerosol
# 	issue Modeling realm: atmosChem
# issues/AERmon.c4h10
# 	dr    modeling_realm: atmosChem aerosol
# 	issue Modeling realm: atmosChem
# issues/Amon.cfc11global
# 	dr    branded_variable_name: cfc11_tavg-u-hm-air
# 	issue Branded variable name: cfc11_tavg-u-hm-u
# issues/Amon.cfc113global
# 	dr    branded_variable_name: cfc113_tavg-u-hm-air
# 	issue Branded variable name: cfc113_tavg-u-hm-u
# issues/Amon.cfc12global
# 	dr    branded_variable_name: cfc12_tavg-u-hm-air
# 	issue Branded variable name: cfc12_tavg-u-hm-u
# issues/AERmon.ch3oh
# 	dr    modeling_realm: atmosChem aerosol
# 	issue Modeling realm: atmosChem
# issues/AERmon.ch4
# 	dr    modeling_realm: atmosChem aerosol
# 	issue Modeling realm: atmosChem
# issues/Amon.ch4
# 	dr    processing_note: For some simulations (e.g., prescribed concentration pi-control run), this will not vary from one year to the next, and so report instead the variable described in the next table entry. If CH4 is spatially uniform, omit this field, but report Global Mean Mole Fraction of CH4 (see the table entry after the next one).  Are these the preferred units or should it be a unitless fraction? Should this field be reported instead on model levels? Or should we also require either the vertically integrated mole fraction (or mass?) of this species or the vertically integrated globally averaged mole fraction (or mass?)? CHANGE SINCE CMIP6 in Cell Methods - CMIP6:time: mean CMIP7:area: time: mean where air,
# ...
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# issues/SImon.sitempbot
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# issues/SImon.sitempsnic
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# issues/SIday.sithick
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	dr    modeling_realm: seaIce ocean
# 	issue Modeling realm: seaIce
# Nope: issues/SImon.sithickSouth30
# issues/SImon.sithick
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	dr    modeling_realm: seaIce ocean
# 	issue Modeling realm: seaIce
# Nope: issues/SImon.sitimefracSouth30
# issues/SIday.siu
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# Nope: issues/SImon.siuSouth30
# issues/SImon.siu
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# issues/SIday.siv
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# Nope: issues/SImon.sivSouth30
# issues/SImon.siv
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# issues/SIday.sisnthick
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. ; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where snow over sea_ice area: time: mean where sea_ice CMIP7:area: time: mean where snow (for snow on sea ice only),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where snow over sea_ice area: time: mean where sea_ice CMIP7:area: time: mean where snow (for snow on sea ice only),
# Nope: issues/SImon.sisnthickSouth30
# issues/SImon.sisnthick
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.;  CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where snow over sea_ice area: time: mean where sea_ice CMIP7:area: time: mean where snow (for snow on sea ice only),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: mean where snow over sea_ice area: time: mean where sea_ice CMIP7:area: time: mean where snow (for snow on sea ice only),
# issues/SIday.sitemptop
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# Nope: issues/SImon.sitemptopSouth30
# issues/SImon.sitemptop
# 	dr    processing_note: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail.; CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),
# 	issue Processing notes: Note that SIMIP requests the area-weighted average for all intensive variables (i.e., variables that are not proportional to area fraction such as albedo, temperature, or heat flux). Hence, all time samples with non-zero sea-ice fraction are first multiplied by area fraction, then summed, and then divided by the sum of the area fractions. See Appendix C of Notz et al. (2016) for more detail. CHANGE SINCE CMIP6 in Cell Methods - CMIP6:area: time: mean where sea_ice (comment: mask=siconc) CMIP7:area: time: mean where sea_ice (mask=siconc),

# %%
missing
# Out:
# ['issues/AERmon.ccnSouth30',
#  'issues/AERmon.ccn1South30',
#  'issues/AERmon.ccn02South30',
#  'issues/AERmon.cdncSouth30',
#  'issues/AERmon.codSouth30',
#  'issues/AERmon.emidmsSouth30',
#  'issues/AERmon.emissSouth30',
#  'issues/AERmon.mmrbcSouth30',
#  'issues/AERmon.mmrdustSouth30',
#  'issues/AERmon.mmrnh4South30',
#  'issues/AERmon.mmrno3South30',
#  'issues/AERmon.mmroaSouth30',
#  'issues/AERmon.mmrpm1South30',
#  'issues/AERmon.mmrpm2p5South30',
#  'issues/AERmon.mmrso4South30',
#  'issues/AERmon.mmrsoaSouth30',
#  'issues/AERmon.mmrssSouth30',
#  'issues/AERmon.od550aerSouth30',
#  'issues/AERmon.reffclwtopSouth30',
#  'issues/AERmon.mmrpm10South30',
#  'issues/AERmon.so2South30',
#  'issues/CFmon.albisccpSouth30',
#  'issues/Amon.clSouth30',
#  'issues/CFmon.clcSouth30',
#  'issues/CFmon.clhcalipsoSouth30',
#  'issues/CFmon.clmcalipsoSouth30',
#  'issues/CFmon.cllcalipsoSouth30',
#  'issues/CFmon.clcalipsoSouth30',
#  'issues/Amon.cliSouth30',
#  'issues/CFmon.clicSouth30',
#  'issues/CFmon.clisSouth30',
#  'issues/CFmon.clisccpSouth30',
#  'issues/Amon.cliviSouth30',
#  'issues/CFmon.clivimodisSouth30',
#  'issues/CFmon.clmodisSouth30',
#  'issues/CFmon.clmodisiceSouth30',
#  'issues/CFmon.clmodisliquidSouth30',
#  'issues/CFmon.clsSouth30',
#  'issues/Amon.cltSouth30',
#  'issues/CFmon.cltcalipsoSouth30',
#  'issues/CFmon.cltisccpSouth30',
#  'issues/CFmon.cltmodisSouth30',
#  'issues/Amon.clwSouth30',
#  'issues/CFmon.clwcSouth30',
#  'issues/CFmon.clwsSouth30',
#  'issues/Amon.clwviSouth30',
#  'issues/CFmon.clwvimodisSouth30',
#  'issues/CFmon.dmcSouth30',
#  'issues/CFmon.edtSouth30',
#  'issues/CFmon.evuSouth30',
#  'issues/Amon.hflsSouth30',
#  'issues/Amon.hfssSouth30',
#  'issues/CFmon.hurSouth30',
#  'issues/Amon.hurSouth30',
#  'issues/E1hr.hursSouth30',
#  'issues/Amon.hursSouth30',
#  'issues/CFmon.husSouth30',
#  'issues/Amon.husSouth30',
#  'issues/Amon.hussSouth30',
#  'issues/CFmon.mcdSouth30',
#  'issues/CFmon.mcuSouth30',
#  'issues/CFmon.pctisccpSouth30',
#  'issues/Amon.pfullSouth30',
#  'issues/E1hr.prSouth30',
#  'issues/Amon.prSouth30',
#  'issues/Amon.prcSouth30',
#  'issues/Amon.prraSouth30',
#  'issues/Amon.prsnSouth30',
#  'issues/Amon.prwSouth30',
#  'issues/Amon.psSouth30',
#  'issues/E1hr.psSouth30',
#  'issues/Amon.pslSouth30',
#  'issues/Emon.reffclicSouth30',
#  'issues/Emon.reffclisSouth30',
#  'issues/Emon.reffclwcSouth30',
#  'issues/Emon.reffclwsSouth30',
#  'issues/E1hr.rldsSouth30',
#  'issues/Amon.rldsSouth30',
#  'issues/Amon.rldscsSouth30',
#  'issues/Amon.rlusSouth30',
#  'issues/Amon.rlutSouth30',
#  'issues/Amon.rlutcsSouth30',
#  'issues/E1hr.rsdsSouth30',
#  'issues/Amon.rsdsSouth30',
#  'issues/Amon.rsdscsSouth30',
#  'issues/Amon.rsdtSouth30',
#  'issues/Amon.rsusSouth30',
#  'issues/Amon.rsuscsSouth30',
#  'issues/Amon.rsutSouth30',
#  'issues/Amon.rsutcsSouth30',
#  'issues/E1hr.sfcWindSouth30',
#  'issues/Amon.sfcWindSouth30',
#  'issues/CFmon.taSouth30',
#  'issues/Amon.taSouth30',
#  'issues/Amon.tasSouth30',
#  'issues/Amon.tasmaxSouth30',
#  'issues/Amon.tasminSouth30',
#  'issues/Amon.tsSouth30',
#  'issues/Amon.uaSouth30',
#  'issues/Amon.uasSouth30',
#  'issues/Amon.vaSouth30',
#  'issues/Amon.vasSouth30',
#  'issues/Amon.wapSouth30',
#  'issues/Amon.zgSouth30',
#  'issues/AERmon.dmsSouth30',
#  'issues/fx.orogSouth30',
#  'issues/E1hr.tasSouth30',
#  'issues/Omon.hfdsSouth30',
#  'issues/Omon.mlotstSouth30',
#  'issues/Omon.soSouth30',
#  'issues/Omon.sosgaSouth30',
#  'issues/Omon.thetaoSouth30',
#  'issues/Omon.tosSouth30',
#  'issues/Omon.umoSouth30',
#  'issues/Omon.uoSouth30',
#  'issues/Omon.vmoSouth30',
#  'issues/Omon.voSouth30',
#  'issues/Omon.wmoSouth30',
#  'issues/Omon.woSouth30',
#  'issues/Omon.zosSouth30',
#  'issues/Omon.calcosSouth30',
#  'issues/Omon.chlosSouth30',
#  'issues/Omon.dfeosSouth30',
#  'issues/Omon.dmsosSouth30',
#  'issues/Omon.grazSouth30',
#  'issues/Omon.intppSouth30',
#  'issues/Omon.intppcalcSouth30',
#  'issues/Omon.intppdiatSouth30',
#  'issues/Omon.intppdiazSouth30',
#  'issues/Omon.intppmiscSouth30',
#  'issues/Omon.intppnitrateSouth30',
#  'issues/Omon.intpppicoSouth30',
#  'issues/Omon.no3osSouth30',
#  'issues/Omon.phosSouth30',
#  'issues/Omon.phycosSouth30',
#  'issues/Omon.pposSouth30',
#  'issues/Omon.spco2South30',
#  'issues/SImon.siageSouth30',
#  'issues/SImon.siconcSouth30',
#  'issues/SImon.sithickSouth30',
#  'issues/SImon.sitimefracSouth30',
#  'issues/SImon.siuSouth30',
#  'issues/SImon.sivSouth30',
#  'issues/SImon.sisnthickSouth30',
#  'issues/SImon.sitemptopSouth30']

# %%
with open('changes.json', 'w') as fh:
    json.dump(changes_dict, fh, indent=4)

# %%
len(todo)
# Out:
# 535

# %%
len(title_changes)
# Out:
# 62

# %%
change_type_count
# Out:
# defaultdict(int,
#             {'modeling_realm': 236,
#              'processing_note': 296,
#              'branded_variable_name': 62,
#              'dimensions': 45,
#              'standard_name': 2,
#              'units': 2,
#              'comment': 64,
#              'long_name': 6,
#              'region': 1,
#              'cmip6_compound_name': 8,
#              'cell_methods': 6})

# %%
title_changes
# Out:
# [[146, 'Variable aerosol.ec550aer.tpt-al-hxy-u.6hr.glb (6hrLev.ec550aer)'],
#  [322, 'Variable aerosol.emilnox.tavg-u-hxy-u.mon.glb (AERmon.emilnox)'],
#  [800, 'Variable atmos.ts.tavg-u-hxy-lnd.day.glb (Eday.tsns)'],
#  [5, 'Variable atmosChem.cfc11.tavg-u-hm-air.mon.glb (Amon.cfc11global)'],
#  [4, 'Variable atmosChem.cfc113.tavg-u-hm-air.mon.glb (Amon.cfc113global)'],
#  [6, 'Variable atmosChem.cfc12.tavg-u-hm-air.mon.glb (Amon.cfc12global)'],
#  [9, 'Variable atmosChem.ch4.tavg-u-hm-air.mon.glb (Amon.ch4global)'],
#  [10, 'Variable atmosChem.ch4.tclm-u-hm-air.mon.glb (Amon.ch4globalClim)'],
#  [296, 'Variable atmosChem.emiavnox.tavg-u-hxy-u.mon.glb (AERmon.emiavnox)'],
#  [26, 'Variable atmosChem.hcfc22.tavg-u-hm-air.mon.glb (Amon.hcfc22global)'],
#  [36, 'Variable atmosChem.n2o.tavg-u-hm-air.mon.glb (Amon.n2oglobal)'],
#  [37, 'Variable atmosChem.n2o.tclm-u-hm-air.mon.glb (Amon.n2oglobalClim)'],
#  [1109, 'Variable land.areacellg.ti-u-hxy-u.fx.grl (IfxGre.areacellg)'],
#  [1845, 'Variable land.areacellr.ti-u-hxy-u.fx.glb (fx.areacellr)'],
#  [719, 'Variable land.esn.tavg-u-hxy-lnd.day.glb (Eday.esn)'],
#  [669, 'Variable land.tas.tavg-h2m-hxy-u.1hr.glb (E1hr.tas)'],
#  [1835, 'Variable land.tslsi.tavg-u-hxy-lsi.day.glb (day.tslsi)'],
#  [1263, 'Variable landIce.tas.tavg-h2m-hxy-is.mon.glb (LImon.tasIs)'],
#  [1571, 'Variable ocean.swhmax.tmax-u-hxy-sea.mon.glb (Omon.swhmax)'],
#  [133, 'Variable ocean.swhmax.tpt-u-hxy-sea.3hr.glb (3hrPt.swhmax)'],
#  [1378, 'Variable ocnBgchem.arag.tavg-ols-hxy-sea.mon.glb (Omon.aragos)'],
#  [1379, 'Variable ocnBgchem.bacc.tavg-ols-hxy-sea.mon.30S-90S (Omon.baccos)'],
#  [1383, 'Variable ocnBgchem.calc.tavg-ols-hxy-sea.mon.glb (Omon.calcos)'],
#  [1310, 'Variable ocnBgchem.chl.tavg-ols-hxy-sea.day.glb (Oday.chlos)'],
#  [1394, 'Variable ocnBgchem.chl.tavg-ols-hxy-sea.mon.glb (Omon.chlos)'],
#  [1387,
#   'Variable ocnBgchem.chlcalc.tavg-ols-hxy-sea.mon.30S-90S (Omon.chlcalcos)'],
#  [1389,
#   'Variable ocnBgchem.chldiat.tavg-ols-hxy-sea.mon.30S-90S (Omon.chldiatos)'],
#  [1391,
#   'Variable ocnBgchem.chldiaz.tavg-ols-hxy-sea.mon.30S-90S (Omon.chldiazos)'],
#  [1393,
#   'Variable ocnBgchem.chlmisc.tavg-ols-hxy-sea.mon.30S-90S (Omon.chlmiscos)'],
#  [1396,
#   'Variable ocnBgchem.chlpico.tavg-ols-hxy-sea.mon.30S-90S (Omon.chlpicoos)'],
#  [1312, 'Variable ocnBgchem.co3.tavg-ols-hxy-sea.day.glb (Oday.co3os)'],
#  [1314,
#   'Variable ocnBgchem.co3satarag.tavg-ols-hxy-sea.day.glb (Oday.co3sataragos)'],
#  [1399, 'Variable ocnBgchem.dfe.tavg-ols-hxy-sea.mon.glb (Omon.dfeos)'],
#  [1401,
#   'Variable ocnBgchem.dissi13c.tavg-ols-hxy-sea.mon.glb (Omon.dissi13cos)'],
#  [1403,
#   'Variable ocnBgchem.dissi14cabio.tavg-ols-hxy-sea.mon.glb (Omon.dissi14cabioos)'],
#  [1405,
#   'Variable ocnBgchem.dissic.tavg-ols-hxy-sea.mon.30S-90S (Omon.dissicos)'],
#  [1408, 'Variable ocnBgchem.dmso.tavg-ols-hxy-sea.mon.glb (Omon.dmsos)'],
#  [1518, 'Variable ocnBgchem.nh4.tavg-ols-hxy-sea.mon.30S-90S (Omon.nh4os)'],
#  [1520, 'Variable ocnBgchem.no3.tavg-ols-hxy-sea.mon.glb (Omon.no3os)'],
#  [1325, 'Variable ocnBgchem.o2.tavg-ols-hxy-sea.day.glb (Oday.o2os)'],
#  [1522, 'Variable ocnBgchem.o2.tavg-ols-hxy-sea.mon.glb (Omon.o2os)'],
#  [1327, 'Variable ocnBgchem.ph.tavg-ols-hxy-sea.day.glb (Oday.phos)'],
#  [1334, 'Variable ocnBgchem.phyc.tavg-ols-hxy-sea.day.glb (Oday.phycos)'],
#  [1534, 'Variable ocnBgchem.phyc.tavg-ols-hxy-sea.mon.glb (Omon.phycos)'],
#  [1533,
#   'Variable ocnBgchem.phycalc.tavg-ols-hxy-sea.mon.30S-90S (Omon.phycalcos)'],
#  [1330,
#   'Variable ocnBgchem.phydiat.tavg-ols-hxy-sea.day.glb (Oday.phydiatos)'],
#  [1536,
#   'Variable ocnBgchem.phydiat.tavg-ols-hxy-sea.mon.30S-90S (Omon.phydiatos)'],
#  [1331,
#   'Variable ocnBgchem.phydiaz.tavg-ols-hxy-sea.day.glb (Oday.phydiazos)'],
#  [1538,
#   'Variable ocnBgchem.phydiaz.tavg-ols-hxy-sea.mon.30S-90S (Omon.phydiazos)'],
#  [1332,
#   'Variable ocnBgchem.phymisc.tavg-ols-hxy-sea.day.glb (Oday.phymiscos)'],
#  [1540,
#   'Variable ocnBgchem.phymisc.tavg-ols-hxy-sea.mon.30S-90S (Omon.phymiscos)'],
#  [1542,
#   'Variable ocnBgchem.phypico.tavg-ols-hxy-sea.mon.30S-90S (Omon.phypicoos)'],
#  [1545, 'Variable ocnBgchem.pp.tavg-ols-hxy-sea.mon.glb (Omon.ppos)'],
#  [1559, 'Variable ocnBgchem.si.tavg-ols-hxy-sea.mon.glb (Omon.sios)'],
#  [1611,
#   'Variable ocnBgchem.zmeso.tavg-ols-hxy-sea.mon.30S-90S (Omon.zmesoos)'],
#  [1613,
#   'Variable ocnBgchem.zmicro.tavg-ols-hxy-sea.mon.30S-90S (Omon.zmicroos)'],
#  [1615,
#   'Variable ocnBgchem.zmisc.tavg-ols-hxy-sea.mon.30S-90S (Omon.zmiscos)'],
#  [1617, 'Variable ocnBgchem.zooc.tavg-ols-hxy-sea.mon.30S-90S (Omon.zoocos)'],
#  [1685, 'Variable seaIce.sisnmass.tavg-u-hm-si.day.nh (SIday.sisnmassn)'],
#  [1686, 'Variable seaIce.sisnmass.tavg-u-hm-si.day.sh (SIday.sisnmasss)'],
#  [1775, 'Variable seaIce.sisnmass.tavg-u-hm-si.mon.nh (SImon.sisnmassn)'],
#  [1776, 'Variable seaIce.sisnmass.tavg-u-hm-si.mon.sh (SImon.sisnmasss)']]

# %%
len(title_changes)
# Out:
# 62

# %%
with open('title_renames_bv_changes.txt', 'w') as fh:
    for i, new_title in title_changes:
        fh.write(f'gh issue edit {i} --title "{new_title}"\n')

# %%
with open('all_issue_updates.txt', 'w') as fh:
    for i, filename in changed_issues:
        fh.write(f'gh issue edit {i} -F {filename}\n')

# %%
# check everything is readable

for cmip7_cn, v in data_v1223.items():
    cmip6_cn = v['cmip6_compound_name']
    filename = f'issues/{cmip6_cn}'
    if not os.path.exists(filename):
        print(f"Nope: {filename}")
        missing.append(filename)
        continue
            
    dri = DRIssue()
    dri.read_file(filename)
# Out:
# Nope: issues/AERmon.ccnSouth30
# Nope: issues/AERmon.ccn1South30
# Nope: issues/AERmon.ccn02South30
# Nope: issues/AERmon.cdncSouth30
# Nope: issues/AERmon.codSouth30
# Nope: issues/AERmon.emidmsSouth30
# Nope: issues/AERmon.emissSouth30
# Nope: issues/AERmon.mmrbcSouth30
# Nope: issues/AERmon.mmrdustSouth30
# Nope: issues/AERmon.mmrnh4South30
# Nope: issues/AERmon.mmrno3South30
# Nope: issues/AERmon.mmroaSouth30
# Nope: issues/AERmon.mmrpm1South30
# Nope: issues/AERmon.mmrpm2p5South30
# Nope: issues/AERmon.mmrso4South30
# Nope: issues/AERmon.mmrsoaSouth30
# Nope: issues/AERmon.mmrssSouth30
# Nope: issues/AERmon.od550aerSouth30
# Nope: issues/AERmon.reffclwtopSouth30
# Nope: issues/AERmon.mmrpm10South30
# Nope: issues/AERmon.so2South30
# Nope: issues/CFmon.albisccpSouth30
# Nope: issues/Amon.clSouth30
# Nope: issues/CFmon.clcSouth30
# Nope: issues/CFmon.clhcalipsoSouth30
# Nope: issues/CFmon.clmcalipsoSouth30
# Nope: issues/CFmon.cllcalipsoSouth30
# Nope: issues/CFmon.clcalipsoSouth30
# Nope: issues/Amon.cliSouth30
# Nope: issues/CFmon.clicSouth30
# Nope: issues/CFmon.clisSouth30
# Nope: issues/CFmon.clisccpSouth30
# Nope: issues/Amon.cliviSouth30
# Nope: issues/CFmon.clivimodisSouth30
# Nope: issues/CFmon.clmodisSouth30
# Nope: issues/CFmon.clmodisiceSouth30
# Nope: issues/CFmon.clmodisliquidSouth30
# Nope: issues/CFmon.clsSouth30
# Nope: issues/Amon.cltSouth30
# Nope: issues/CFmon.cltcalipsoSouth30
# Nope: issues/CFmon.cltisccpSouth30
# Nope: issues/CFmon.cltmodisSouth30
# Nope: issues/Amon.clwSouth30
# Nope: issues/CFmon.clwcSouth30
# Nope: issues/CFmon.clwsSouth30
# Nope: issues/Amon.clwviSouth30
# Nope: issues/CFmon.clwvimodisSouth30
# Nope: issues/CFmon.dmcSouth30
# Nope: issues/CFmon.edtSouth30
# Nope: issues/CFmon.evuSouth30
# Nope: issues/Amon.hflsSouth30
# Nope: issues/Amon.hfssSouth30
# Nope: issues/CFmon.hurSouth30
# Nope: issues/Amon.hurSouth30
# Nope: issues/E1hr.hursSouth30
# Nope: issues/Amon.hursSouth30
# Nope: issues/CFmon.husSouth30
# Nope: issues/Amon.husSouth30
# Nope: issues/Amon.hussSouth30
# Nope: issues/CFmon.mcdSouth30
# Nope: issues/CFmon.mcuSouth30
# Nope: issues/CFmon.pctisccpSouth30
# Nope: issues/Amon.pfullSouth30
# Nope: issues/E1hr.prSouth30
# Nope: issues/Amon.prSouth30
# Nope: issues/Amon.prcSouth30
# Nope: issues/Amon.prraSouth30
# Nope: issues/Amon.prsnSouth30
# Nope: issues/Amon.prwSouth30
# Nope: issues/Amon.psSouth30
# Nope: issues/E1hr.psSouth30
# Nope: issues/Amon.pslSouth30
# Nope: issues/Emon.reffclicSouth30
# Nope: issues/Emon.reffclisSouth30
# Nope: issues/Emon.reffclwcSouth30
# Nope: issues/Emon.reffclwsSouth30
# Nope: issues/E1hr.rldsSouth30
# Nope: issues/Amon.rldsSouth30
# Nope: issues/Amon.rldscsSouth30
# Nope: issues/Amon.rlusSouth30
# Nope: issues/Amon.rlutSouth30
# Nope: issues/Amon.rlutcsSouth30
# Nope: issues/E1hr.rsdsSouth30
# Nope: issues/Amon.rsdsSouth30
# Nope: issues/Amon.rsdscsSouth30
# Nope: issues/Amon.rsdtSouth30
# Nope: issues/Amon.rsusSouth30
# Nope: issues/Amon.rsuscsSouth30
# Nope: issues/Amon.rsutSouth30
# Nope: issues/Amon.rsutcsSouth30
# Nope: issues/E1hr.sfcWindSouth30
# Nope: issues/Amon.sfcWindSouth30
# Nope: issues/CFmon.taSouth30
# Nope: issues/Amon.taSouth30
# Nope: issues/Amon.tasSouth30
# Nope: issues/Amon.tasmaxSouth30
# Nope: issues/Amon.tasminSouth30
# Nope: issues/Amon.tsSouth30
# Nope: issues/Amon.uaSouth30
# Nope: issues/Amon.uasSouth30
# Nope: issues/Amon.vaSouth30
# Nope: issues/Amon.vasSouth30
# Nope: issues/Amon.wapSouth30
# Nope: issues/Amon.zgSouth30
# Nope: issues/AERmon.dmsSouth30
# Nope: issues/fx.orogSouth30
# Nope: issues/E1hr.tasSouth30
# Nope: issues/Omon.hfdsSouth30
# Nope: issues/Omon.mlotstSouth30
# Nope: issues/Omon.soSouth30
# Nope: issues/Omon.sosgaSouth30
# Nope: issues/Omon.thetaoSouth30
# Nope: issues/Omon.tosSouth30
# Nope: issues/Omon.umoSouth30
# Nope: issues/Omon.uoSouth30
# Nope: issues/Omon.vmoSouth30
# Nope: issues/Omon.voSouth30
# Nope: issues/Omon.wmoSouth30
# Nope: issues/Omon.woSouth30
# Nope: issues/Omon.zosSouth30
# Nope: issues/Omon.calcosSouth30
# Nope: issues/Omon.chlosSouth30
# Nope: issues/Omon.dfeosSouth30
# Nope: issues/Omon.dmsosSouth30
# Nope: issues/Omon.grazSouth30
# Nope: issues/Omon.intppSouth30
# Nope: issues/Omon.intppcalcSouth30
# Nope: issues/Omon.intppdiatSouth30
# Nope: issues/Omon.intppdiazSouth30
# Nope: issues/Omon.intppmiscSouth30
# Nope: issues/Omon.intppnitrateSouth30
# Nope: issues/Omon.intpppicoSouth30
# Nope: issues/Omon.no3osSouth30
# Nope: issues/Omon.phosSouth30
# Nope: issues/Omon.phycosSouth30
# Nope: issues/Omon.pposSouth30
# Nope: issues/Omon.spco2South30
# Nope: issues/SImon.siageSouth30
# Nope: issues/SImon.siconcSouth30
# Nope: issues/SImon.sithickSouth30
# Nope: issues/SImon.sitimefracSouth30
# Nope: issues/SImon.siuSouth30
# Nope: issues/SImon.sivSouth30
# Nope: issues/SImon.sisnthickSouth30
# Nope: issues/SImon.sitemptopSouth30
